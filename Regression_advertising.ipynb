# %%
'''
Regression: Simple Linear 
Dataset: advertising.csv 
Apply Data pre-processing (Label Encoding , Data Transformation….) techniques if necessary. 
Explore whether TV advertising spending can predict the number of sales for the product.
Also display the regression results and plot the regression line. 
'''
# Out:
# '\nRegression: Simple Linear \nDataset: advertising.csv \nApply Data pre-processing (Label Encoding , Data Transformation….) techniques if necessary. Explore whether TV advertising spending can predict the number of sales for the product. Also display the regression results and plot the regression line. \n'

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, r2_score, mean_squared_error
from sklearn.model_selection import train_test_split

# %%
data = pd.read_csv(r'LP-1_Dataset\Regression\advertising.csv')

data.head()
# Out:
#       TV  Radio  Newspaper  Sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3   12.0
# 3  151.5   41.3       58.5   16.5
# 4  180.8   10.8       58.4   17.9

# %%
data.isnull().sum()
# Out:
# TV           0
# Radio        0
# Newspaper    0
# Sales        0
# dtype: int64

# %%
X = data[['TV']]
y = data['Sales']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X_test)

# %%
slope = model.coef_[0]
coefficient = model.coef_
intercept = model.intercept_
rss = np.sum((y_test - y_pred) ** 2)
mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
r2 = r2_score(y_test, y_pred)
n = len(y_test)
p = 1
adjusted_r2 = 1 - (1 - r2) * (n - 1) / (n - p - 1)

print("Slope: ", slope)
print("Coefficient: ", coefficient)
print("Intercept: ", intercept)
print("RSS: ", rss)
print("MAE: ", mae)
print("MSE: ", mse)
print("RMSE: ", rmse)
print("R^2: ", r2)
print("Adjusted R^2: ", adjusted_r2)
# Out:
# Slope:  0.05483488379527938
# Coefficient:  [0.05483488]
# Intercept:  7.206554548173253
# RSS:  310.7715241299992
# MAE:  1.8069123776641516
# MSE:  5.179525402166653
# RMSE:  2.2758570698017597
# R^2:  0.814855389208679
# Adjusted R^2:  0.8116632407467597

# %%
plt.figure(figsize=(10, 6))
plt.scatter(X, y, color='blue', label="Actual Data")
plt.plot(X, model.predict(X), color='red', label="Regression Line")
plt.xlabel("TV")
plt.ylabel("Sales")
plt.title("TV Advertising vs Sales")
plt.legend()
plt.show()

# %%
'''
Regression: Simple Linear 
Dataset: advertising.csv 
Apply Data pre-processing (Label Encoding , Data Transformation….) techniques if necessary. Explore whether Radio advertising spending can predict the number of sales for the product. Also display the regression results and plot the regression line. 
'''
# Out:
# '\nRegression: Simple Linear \nDataset: advertising.csv \nApply Data pre-processing (Label Encoding , Data Transformation….) techniques if necessary. Explore whether Radio advertising spending can predict the number of sales for the product. Also display the regression results and plot the regression line. \n'

# %%
data = pd.read_csv(r'LP-1_Dataset\Regression\advertising.csv')

data.head()
# Out:
#       TV  Radio  Newspaper  Sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3   12.0
# 3  151.5   41.3       58.5   16.5
# 4  180.8   10.8       58.4   17.9

# %%
X = data[['Radio']]
y = data['Sales']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

model = LinearRegression()
model.fit(X_train, y_train)

y_pred = model.predict(X_test)

# %%
slope = model.coef_[0]
coefficient = model.coef_
intercept = model.intercept_
rss = np.sum((y_test - y_pred) ** 2)
mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
r2 = r2_score(y_test, y_pred)
n = len(y_test)
p = 1
adjusted_r2 = 1 - (1 - r2) * (n - 1) / (n - p - 1)

print("Slope: ", slope)
print("Coefficient: ", coefficient)
print("Intercept: ", intercept)
print("RSS: ", rss)
print("MAE: ", mae)
print("MSE: ", mse)
print("RMSE: ", rmse)
print("R^2: ", r2)
print("Adjusted R^2: ", adjusted_r2)
# Out:
# Slope:  0.12679502270828677
# Coefficient:  [0.12679502]
# Intercept:  12.799289947930411
# RSS:  1752.9632891565182
# MAE:  4.6489470961606
# MSE:  29.216054819275303
# RMSE:  5.405187769104354
# R^2:  -0.044341841843250185
# Adjusted R^2:  -0.0623477356681339

# %%
plt.figure(figsize=(10, 6))
plt.scatter(X, y, color='blue', label="Actual Data")
plt.plot(X, model.predict(X), color='red', label="Regression Line")
plt.xlabel("Radio")
plt.ylabel("Sales")
plt.title("Radio Advertising vs Sales")
plt.legend()
plt.show()

# %%
'''
Regression: Simple Linear 
Dataset: advertising.csv 
Apply Data pre-processing (Label Encoding , Data Transformation….) techniques if necessary. Explore whether Newspaper advertising spending can predict the number of sales for the product. Also display the regression results and plot the regression line. 
'''
# Out:
# '\nRegression: Simple Linear \nDataset: advertising.csv \nApply Data pre-processing (Label Encoding , Data Transformation….) techniques if necessary. Explore whether Newspaper advertising spending can predict the number of sales for the product. Also display the regression results and plot the regression line. \n'

# %%
data = pd.read_csv(r'LP-1_Dataset\Regression\advertising.csv')

data.head()

X = data[['Newspaper']]
y = data['Sales']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

model = LinearRegression()
model.fit(X_train, y_train)

y_pred = model.predict(X_test)

slope = model.coef_[0]
coefficient = model.coef_
intercept = model.intercept_
rss = np.sum((y_test - y_pred) ** 2)
mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
r2 = r2_score(y_test, y_pred)
n = len(y_test)
p = 1
adjusted_r2 = 1 - (1 - r2) * (n - 1) / (n - p - 1)

print("Slope: ", slope)
print("Coefficient: ", coefficient)
print("Intercept: ", intercept)
print("RSS: ", rss)
print("MAE: ", mae)
print("MSE: ", mse)
print("RMSE: ", rmse)
print("R^2: ", r2)
print("Adjusted R^2: ", adjusted_r2)

plt.figure(figsize=(10, 6))
plt.scatter(X, y, color='blue', label="Actual Data")
plt.plot(X, model.predict(X), color='red', label="Regression Line")
plt.xlabel("Newspaper")
plt.ylabel("Sales")
plt.title("Newspaper Advertising vs Sales")
plt.legend()
plt.show()
# Out:
# Slope:  0.03993515057993135
# Coefficient:  [0.03993515]
# Intercept:  14.566203097306618
# RSS:  1919.325311807337
# MAE:  4.808108707883894
# MSE:  31.988755196788947
# RMSE:  5.655860252586599
# R^2:  -0.14345334190867565
# Adjusted R^2:  -0.16316805470020457
